# %%
import h5py
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

filename = '/content/drive/MyDrive/loadwalks.py'
exec(open(filename).read())

filename = '/content/drive/MyDrive/confidenceintervals.py'
exec(open(filename).read())


path1 = '/content/drive/My Drive/CapstoneWalks/150Dim_1250Steps_Walks.h5'
path2 = '/content/drive/My Drive/CapstoneWalks/Corner150Dim_1250Steps_Walks_Test.h5'

path3 = '/content/drive/MyDrive/CapstoneWalks/Corner150Dim_1250Steps_Targets.h5'
path4 = '/content/drive/MyDrive/CapstoneWalks/Corner150Dim_1250Steps_Targets_Test.h5'

Walks_Training = read_one_hdf5(path1)
Walks_Testing = read_one_hdf5(path2)
Walk_Targets = read_one_hdf5(path3)
Walk_Targets_Test = read_one_hdf5(path4)
# Out:
# Completed
# Completed
# Completed
# Completed

# %%
steps = 1250
Walks_Training = Walks_Training/steps
Walks_Testing = Walks_Testing/steps

# %%
from keras.layers import Input
#Using grayscale images
in_channel = 1
num_targets = 4
img_rows, img_cols = 150, 150

input_shape = (img_rows, img_cols, in_channel)

input_img = Input(shape = input_shape)

# %%
import keras
from keras.layers import Input, Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Activation, concatenate
from keras.layers.advanced_activations import ReLU
from keras.models import Model




def create_sub_graph_CNN(input_img):
  
  model = Conv2D(32, (3, 3), padding='same')(input_img)
  model = ReLU()(model)
  model = MaxPooling2D((2, 2),padding='same')(model)

  model = Conv2D(64, (3, 3), padding='same')(model)
  model = ReLU()(model)
  model = MaxPooling2D(pool_size=(2, 2),padding='same')(model)
  
  model = Conv2D(32, (3, 3), padding='same')(model)
  model = ReLU()(model)
  model = MaxPooling2D(pool_size=(2, 2),padding='same')(model)
  
  model = Flatten()(model)
  return model

# %%
#Create input and model framework for Rand Walks models

xSmall_input = Input(shape=input_shape)

walks_model0 = create_sub_graph_CNN(xSmall_input)
walks_model1 =create_sub_graph_CNN(xSmall_input)
walks_model2 = create_sub_graph_CNN(xSmall_input)
walks_model3 = create_sub_graph_CNN(xSmall_input)

walks_model4 = create_sub_graph_CNN(xSmall_input)
walks_model5 = create_sub_graph_CNN(xSmall_input)
walks_model6 = create_sub_graph_CNN(xSmall_input)
walks_model7 = create_sub_graph_CNN(xSmall_input)

walks_model8 = create_sub_graph_CNN(xSmall_input)
walks_model9 =create_sub_graph_CNN(xSmall_input)
walks_model10 = create_sub_graph_CNN(xSmall_input)
walks_model11 = create_sub_graph_CNN(xSmall_input)

modelsCNN = [walks_model0,walks_model1,walks_model2,walks_model3,walks_model4,walks_model5,walks_model6,walks_model7,walks_model8,walks_model9,walks_model10,walks_model11]

# %%
from keras.utils.vis_utils import plot_model
from keras import optimizers
import tensorflow as tf

output = Dense(num_targets, activation='sigmoid', use_bias = True)(walks_model0)


ACE = tf.keras.models.Model(xSmall_input, output, name="PACE")


ACE.compile(loss=tf.keras.losses.LogCosh(), optimizer=tf.keras.optimizers.Adam(lr=0.0005), metrics= ['mse'])


plot_model(ACE, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from keras import optimizers
import tensorflow as tf

#Combine results from both models into a larger 2D matrix
combined = concatenate([model for model in modelsCNN])

#Flatten creates a resized vector to be fed into final prediction
combined = Flatten()(combined)
#combined = Dropout(.5)(combined)

output = Dense(num_targets, activation='sigmoid', use_bias = True)(combined)


ACE = tf.keras.models.Model(xSmall_input, output, name="Very_Small_Walks_Ensemble_CNN")


ACE.compile(loss=tf.keras.losses.LogCosh(), optimizer=tf.keras.optimizers.Adam(lr=0.0005), metrics= ['mse'])

# %%
ACE.summary()
# Out:
# Model: "Very_Small_Walks_Ensemble_CNN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 150, 150, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 150, 150, 32) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 150, 150, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 150, 150, 32) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 150, 150, 32) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 150, 150, 32) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 150, 150, 32) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 150, 150, 32) 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 150, 150, 32) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 150, 150, 32) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 150, 150, 32) 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 150, 150, 32) 0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 150, 150, 32) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 75, 75, 32)   0           re_lu[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 75, 75, 32)   0           re_lu_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 75, 75, 32)   0           re_lu_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 75, 75, 32)   0           re_lu_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_30 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 75, 75, 32)   0           re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 75, 75, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 64)   18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 75, 75, 64)   18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 75, 75, 64)   18496       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 75, 75, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 75, 75, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 75, 75, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 75, 75, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 75, 75, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 75, 75, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 75, 75, 64)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 75, 75, 64)   0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 75, 75, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 75, 75, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 75, 75, 64)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 75, 75, 64)   0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 38, 38, 64)   0           re_lu_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 38, 38, 64)   0           re_lu_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 38, 38, 64)   0           re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_31 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 38, 38, 64)   0           re_lu_34[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 38, 38, 32)   18464       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 38, 38, 32)   18464       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 38, 38, 32)   18464       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 38, 38, 32)   18464       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 38, 38, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 38, 38, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 38, 38, 32)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 38, 38, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 38, 38, 32)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 38, 38, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 38, 38, 32)   0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 38, 38, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 38, 38, 32)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 38, 38, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 38, 38, 32)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 38, 38, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 19, 19, 32)   0           re_lu_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 19, 19, 32)   0           re_lu_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 19, 19, 32)   0           re_lu_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 19, 19, 32)   0           re_lu_35[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 11552)        0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 11552)        0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 11552)        0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 11552)        0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 11552)        0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 11552)        0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 11552)        0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 11552)        0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 11552)        0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 11552)        0           max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 11552)        0           max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 11552)        0           max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 138624)       0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
#                                                                  flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 138624)       0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            554500      flatten_12[0][0]
# ==================================================================================================
# Total params: 1,001,860
# Trainable params: 1,001,860
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
ACE.fit(Walks_Training, Walk_Targets, epochs=15, batch_size= 32,
       shuffle=True, validation_data=(Walks_Testing, Walk_Targets_Test))
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 227s 121ms/step - loss: 0.0042 - mse: 0.0085 - val_loss: 0.0030 - val_mse: 0.0060
# Epoch 2/15
# 1875/1875 [==============================] - 226s 120ms/step - loss: 0.0022 - mse: 0.0044 - val_loss: 0.0023 - val_mse: 0.0047
# Epoch 3/15
# 1875/1875 [==============================] - 226s 120ms/step - loss: 0.0014 - mse: 0.0028 - val_loss: 0.0012 - val_mse: 0.0024
# Epoch 4/15
# 1875/1875 [==============================] - 226s 120ms/step - loss: 0.0011 - mse: 0.0021 - val_loss: 9.6720e-04 - val_mse: 0.0019
# Epoch 5/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 0.0014 - mse: 0.0027 - val_loss: 0.0010 - val_mse: 0.0020
# Epoch 6/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 9.0805e-04 - mse: 0.0018 - val_loss: 8.4745e-04 - val_mse: 0.0017
# Epoch 7/15
# 1875/1875 [==============================] - 226s 120ms/step - loss: 8.4495e-04 - mse: 0.0017 - val_loss: 8.0788e-04 - val_mse: 0.0016
# Epoch 8/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 6.9053e-04 - mse: 0.0014 - val_loss: 6.7486e-04 - val_mse: 0.0014
# Epoch 9/15
# 1875/1875 [==============================] - 226s 120ms/step - loss: 6.3326e-04 - mse: 0.0013 - val_loss: 6.5152e-04 - val_mse: 0.0013
# Epoch 10/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 5.8882e-04 - mse: 0.0012 - val_loss: 5.9145e-04 - val_mse: 0.0012
# Epoch 11/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 5.5858e-04 - mse: 0.0011 - val_loss: 6.1474e-04 - val_mse: 0.0012
# Epoch 12/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 5.6120e-04 - mse: 0.0011 - val_loss: 5.8316e-04 - val_mse: 0.0012
# Epoch 13/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 5.1471e-04 - mse: 0.0010 - val_loss: 6.3457e-04 - val_mse: 0.0013
# Epoch 14/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 5.0929e-04 - mse: 0.0010 - val_loss: 5.8684e-04 - val_mse: 0.0012
# Epoch 15/15
# 1875/1875 [==============================] - 225s 120ms/step - loss: 4.8809e-04 - mse: 9.7709e-04 - val_loss: 5.5185e-04 - val_mse: 0.0011

# %%
PEC.save('/content/drive/MyDrive/CapstoneWalks/BestModelWeights/Random150x150ACE')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/CapstoneWalks/BestModelWeights/Random150x150ACE/assets

# %%
def RMSE(arr1,arr2):

  r = (arr1-arr2)**2

  r = r.sum()/(4*numWalks)  #Scale down the walks to calculate mean square error

  r = r**.5 #Calculate RMSE for entire model

  return r

# %%
new_Model = keras.models.load_model('/content/drive/MyDrive/CapstoneWalks/BestModelWeights/Corner7x7PACE')

# %%
preds = PEC.predict(Walks_Testing)
preds2 = new_Model.predict(Walks_Testing)
print(RMSE(preds,Walk_Targets_Test))
print(RMSE(preds2,Walk_Targets_Test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-de545f5e1a4d> in <module>()
#       1 preds = PEC.predict(Walks_Testing)
# ----> 2 preds2 = new_Model.predict(Walks_Testing)
#       3 print(RMSE(preds,Walk_Targets_Test))
#       4 print(RMSE(preds2,Walk_Targets_Test))
#
# NameError: name 'new_Model' is not defined

# %%
preds = PEC.predict(Walks_Testing)

sums = [sum(array) for array in preds]
plt.hist(sums)
sum(sums)/len(sums)
report_confidence_interval(confidence_interval(sums, confidence=0.95))
# Out:
# 'our mean lies in the interval ]1.0062, 1.0069['

# %%
report_confidence_interval(confidence_interval(sums, confidence=0.95))
# Out:
# 'our mean lies in the interval ]1.0062, 1.0069['

# %%
PEC.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b047b1d7a5d8> in <module>()
# ----> 1 PEC.summary()
#
# NameError: name 'PEC' is not defined
